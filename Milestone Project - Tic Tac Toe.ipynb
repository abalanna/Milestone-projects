# %%
## previous board - documentation ## 

# input1 = input2 = input3 = input4 = input5 = input6 = input7 = input8 = input9 = 'X'
# board_draw = {1: "_____\n     |\n  {}  |\n     |".format(input1),
#         2: "_____\n     |\n  {}  |\n     |".format(input2),
#         3: "_____\n     \n  {}  \n     ".format(input3),
#         4: "_____\n     |\n  {}  |\n     |".format(input4),
#         5: "_____\n     |\n  {}  |\n     |".format(input5),
#         6: "_____\n     \n  {}  \n     ".format(input6),
#         7: "     |\n  {}  |\n     |".format(input7),
#         8: "     |\n  {}  |\n     |".format(input8),
#         9: "     \n  {}  \n     ".format(input9)}

# board = {b: [7,8,9,4,5,6,1,2,3]}

# for num in board_draw.values():
#     print(board_draw.get(4))

# %%
'''TIC TAC TOE game v. 0.2'''

# import os
print('Welcome to the Tic Tac Toe game!\n')
p1 = input('Player 1: Please choose your symbol (X or O): ')

if p1 == 'X':
    p2 = 'O'
    print('Player 2: Your symbol is: O')
else:
    p2 = 'X'
    print('Player 2: Your symbol is: X')

print('\nThis is your board.\n')


def draw_board():
    '''Returns sample board with cells numbers'''

    db = {789: "     |     |     \n  7  |  8  |  9  \n     |     |     ",
          456: "\n ---------------\n     |     |     \n  4  |  5  |  6  \n     |     |     ",
          123: "\n ---------------\n     |     |     \n  1  |  2  |  3  \n     |     |     "}

    return print(db[789], db[456], db[123])

draw_board()

# cells assigning
c1 = c2 = c3 = c4 = c5 = c6 = c7 = c8 = c9 = ' '

cells = {'1': c1, '2': c2, '3': c3, '4': c4, '5': c5, '6': c6, '7': c7, '8': c8, '9': c9}


def game_board():
    '''Returns current game board'''

    gb = {789: f"\n     |     |     \n  {cells['7']}  |  {cells['8']}  |  {cells['9']}  \n     |     |     ",
          456: f"\n ---------------\n     |     |     \n  {cells['4']}  |  {cells['5']}  |  {cells['6']}  \n     |     |     ",
          123: f"\n ---------------\n     |     |     \n  {cells['1']}  |  {cells['2']}  |  {cells['3']}  \n     |     |     "}

    return print(gb[789], gb[456], gb[123])


# def clear_screen():
#     os.system('cls' if os.name == 'nt' else 'clear')

def p1_move():
    p1_move.counter += 1
    n1 = input('Player 1: Please choose the number to place your symbol: ')
    for key, value in cells.items():
        if n1 == key:
            cells[key] = p1
    return game_board()

def p2_move():
    n2 = input('Player 2: Please choose the number to place your symbol: ')
    for key, value in cells.items():
        if n2 == key:
            cells[key] = p2
    return game_board()
          
p1_move.counter = 0
play = True

while play:
    p1_move()
    # clear_screen()
          
    win = [[cells['1'], cells['2'], cells['3']], [cells['4'], cells['5'], cells['6']], 
           [cells['7'], cells['8'], cells['9']], [cells['7'], cells['4'], cells['1']], 
           [cells['8'], cells['5'], cells['2']], [cells['9'], cells['6'], cells['3']], 
           [cells['7'], cells['5'], cells['3']], [cells['1'], cells['5'], cells['9']]]
          
    if p1_move.counter <= 2:
        p2_move()
    elif p1_move.counter >= 3:
        for w in win:
          if w == [p1, p1, p1]:
              print('\nCongratulations! The winner is Player 1.')
              break
          else: 
              p2_move()
              if w == [p2, p2, p2]:
                  print('\nCongratulations! The winner is Player 2.')
                  break
              else:
                  continue
        break
# Out:
# Welcome to the Tic Tac Toe game!
#
# Player 1: Please choose your symbol (X or O): X
# Player 2: Your symbol is: O
#
# This is your board.
#
#      |     |
#   7  |  8  |  9
#      |     |
#  ---------------
#      |     |
#   4  |  5  |  6
#      |     |
#  ---------------
#      |     |
#   1  |  2  |  3
#      |     |
# Player 1: Please choose the number to place your symbol: 1
#
#      |     |
#      |     |
#      |     |
#  ---------------
#      |     |
#      |     |
#      |     |
#  ---------------
#      |     |
#   X  |     |
#      |     |
# Player 2: Please choose the number to place your symbol: 4
#
#      |     |
#      |     |
#      |     |
#  ---------------
#      |     |
#   O  |     |
#      |     |
#  ---------------
#      |     |
#   X  |     |
#      |     |
# Player 1: Please choose the number to place your symbol: 2
#
#      |     |
#      |     |
#      |     |
#  ---------------
#      |     |
#   O  |     |
#      |     |
#  ---------------
#      |     |
#   X  |  X  |
#      |     |
# Player 2: Please choose the number to place your symbol: 5
#
#      |     |
#      |     |
#      |     |
#  ---------------
#      |     |
#   O  |  O  |
#      |     |
#  ---------------
#      |     |
#   X  |  X  |
#      |     |
# Player 1: Please choose the number to place your symbol: 9
#
#      |     |
#      |     |  X
#      |     |
#  ---------------
#      |     |
#   O  |  O  |
#      |     |
#  ---------------
#      |     |
#   X  |  X  |
#      |     |
# Player 2: Please choose the number to place your symbol: 6
#
#      |     |
#      |     |  X
#      |     |
#  ---------------
#      |     |
#   O  |  O  |  O
#      |     |
#  ---------------
#      |     |
#   X  |  X  |
#      |     |
# Player 2: Please choose the number to place your symbol: 4
#
#      |     |
#      |     |  X
#      |     |
#  ---------------
#      |     |
#   O  |  O  |  O
#      |     |
#  ---------------
#      |     |
#   X  |  X  |
#      |     |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /Applications/anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /Applications/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /Applications/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-11d1776f2f1d> in <module>
#      80               break
#      81           else:
# ---> 82               p2_move()
#      83               if w == [p2, p2, p2]:
#      84                   print('\nCongratulations! The winner is Player 2.')
#
# <ipython-input-8-11d1776f2f1d> in p2_move()
#      54
#      55 def p2_move():
# ---> 56     n2 = input('Player 2: Please choose the number to place your symbol: ')
#      57     for key, value in cells.items():
#      58         if n2 == key:
#
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:
